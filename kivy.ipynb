# %%
#!/usr/bin/env python
from kivy.app import App
from kivy.uix.gridlayout import GridLayout
from kivy.uix.button import Button
from kivy.graphics import Color, Rectangle
import random


def fib_width_height():
    width = 1
    height = 1
    count = 1
    while height < 1000:
        if co:
            height, width = height + width, height
        else:
            width, height = height + width, width
        if height <= 1000:
            yield width, height
        count += 1
    raise StopIteration


class Fib(Button):
    '''
    Draw button graphics
    '''
    def __init__(self, **kwargs):
        super(Fib, self).__init__(**kwargs)
        with self.canvas:
            Color(random.random(), random.random(), random.random(), 0.1,
                  mode="rgba")
            for wid, hei in iter(fib_width_height()):
                print("wid, hei:", wid, hei)
                Rectangle(size=(wid * 0.7, hei * 0.7), pos=(0, 0))


class LoginScreen(GridLayout):
    """A user password screen in a grid layout"""

    def __init__(self, **kwargs):
        super(LoginScreen, self).__init__(**kwargs)
        fib = Fib()
        self.add_widget(fib)


class MyApp(App):
    """The application"""
    def build(self):
        return LoginScreen(size=(800, 800))

if __name__ == '__main__':
    MyApp().run()
# Out:
# [INFO              ] [ProbeSysfs  ] device match: /dev/input/event15
# INFO:kivy:[ProbeSysfs  ] device match: /dev/input/event15
# [INFO              ] [MTD         ] Read event from </dev/input/event15>
# INFO:kivy:[MTD         ] Read event from </dev/input/event15>
# [INFO              ] [Base        ] Start application main loop
# INFO:kivy:[Base        ] Start application main loop
# [WARNING           ] <__main__.LoginScreen object at 0x7f672d29e390> have no cols or rows set, layout is not triggered.
#  Exception in thread Thread-8:
# WARNING:kivy:stderr: Exception in thread Thread-8:
#  Exception in thread Thread-7:
# WARNING:kivy:stderr: Exception in thread Thread-7:
# WARNING:kivy:<__main__.LoginScreen object at 0x7f672d29e390> have no cols or rows set, layout is not triggered.
#  Traceback (most recent call last):
#  Traceback (most recent call last):
#  Exception in thread Thread-9:
# WARNING:kivy:stderr: Traceback (most recent call last):
# ...
